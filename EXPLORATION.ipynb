# %% [markdown]
# # ***HOSPITALITY DATA ANALYSIS***
#
# ---

# %% [markdown]
# ## DATASETS:
#
#
# *   Fact_bookings.csv
# *   Fact_aggregated_bookings
#
# *   Dim_hotels.csv
# *   Dim_date.csv
#
# *   Dim_rooms.csv

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ## Read a dataset from a  csv file

# %%
booking=pd.read_csv("/content/fact_bookings.csv")
agg_booking=pd.read_csv("/content/fact_aggregated_bookings.csv")
date=pd.read_csv("/content/dim_date.csv")
hotel=pd.read_csv("/content/dim_hotel.csv")
rooms=pd.read_csv("/content/dim_rooms.csv")

# %% [markdown]
# ## **1. FACT** **BOOKINGS**

# %% [markdown]
# ### EXPLORATION:

# %% [markdown]
# "Shape represents the number of rows and columns in a dataset"

# %%
booking.shape
# Out:
# (9200, 5)

# %%
booking.head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %% [markdown]
# "The info() method represents the information about the dataframe, it can be the no. of columns, range index, columns data types"

# %%
booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134590 entries, 0 to 134589
# Data columns (total 12 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   booking_id         134590 non-null  object
#  1   property_id        134590 non-null  int64
#  2   booking_date       134590 non-null  object
#  3   check_in_date      134590 non-null  object
#  4   checkout_date      134590 non-null  object
#  5   no_guests          134587 non-null  float64
#  6   room_category      134590 non-null  object
#  7   booking_platform   134590 non-null  object
#  8   ratings_given      56683 non-null   float64
#  9   booking_status     134590 non-null  object
#  10  revenue_generated  134590 non-null  int64
#  11  revenue_realized   134590 non-null  int64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 12.3+ MB

# %% [markdown]
# "The describe() method analyzes both numeric and object series, as well as dataframe columns sets of mixed data types"

# %%
booking.describe()
# Out:
#          property_id      no_guests  ratings_given  revenue_generated  \
# count  134590.000000  134587.000000   56683.000000       1.345900e+05
# mean    18061.113493       2.036170       3.619004       1.537805e+04
# std      1093.055847       1.034885       1.235009       9.303604e+04
# min     16558.000000     -17.000000       1.000000       6.500000e+03
# 25%     17558.000000       1.000000       3.000000       9.900000e+03
# 50%     17564.000000       2.000000       4.000000       1.350000e+04
# 75%     18563.000000       2.000000       5.000000       1.800000e+04
# max     19563.000000       6.000000       5.000000       2.856000e+07
#
#        revenue_realized
# count     134590.000000
# mean       12696.123256
# std         6928.108124
# min         2600.000000
# 25%         7600.000000
# 50%        11700.000000
# 75%        15300.000000
# max        45220.000000

# %% [markdown]
# "The unique() function identifies the distinct elements present within the data"

# %%
booking.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
booking.booking_platform.unique()
# Out:
# array(['direct online', 'others', 'logtrip', 'tripster', 'makeyourtrip',
#        'journey', 'direct offline'], dtype=object)

# %%
booking.booking_status.unique()
# Out:
# array(['Checked Out', 'Cancelled', 'No Show'], dtype=object)

# %%
booking.booking_status.unique()
# Out:
# array(['Checked Out', 'Cancelled', 'No Show'], dtype=object)

# %% [markdown]
# "The value_counts() contains count the no.of unique elements in the columns"

# %%
booking.room_category.value_counts()
# Out:
# room_category
# RT2    49505
# RT1    38446
# RT3    30566
# RT4    16073
# Name: count, dtype: int64

# %%
booking.booking_platform.value_counts()
# Out:
# booking_platform
# others            55066
# makeyourtrip      26898
# logtrip           14756
# direct online     13379
# tripster           9630
# journey            8106
# direct offline     6755
# Name: count, dtype: int64

# %%
booking.booking_status.value_counts()
# Out:
# booking_status
# Checked Out    94411
# Cancelled      33420
# No Show         6759
# Name: count, dtype: int64

# %% [markdown]
# "Groupby() function allows to group data based on a single column or more"

# %%
room_category_grp=booking.groupby("room_category")
room_category_grp.get_group("RT1").head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 1  May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 3  May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 1        2.0           RT1           others            NaN      Cancelled
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 3       -2.0           RT1           others            NaN      Cancelled
# 4        4.0           RT1    direct online            5.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("room_category")
room_category_grp.get_group("RT2").head(5)
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 18  May012216558RT21        16558     7/4/2022      1/5/2022      6/5/2022
# 19  May012216558RT22        16558     30-04-22      1/5/2022      3/5/2022
# 20  May012216558RT23        16558    10/4/2022      1/5/2022      7/5/2022
# 21  May012216558RT24        16558     29-04-22      1/5/2022      3/5/2022
# 22  May012216558RT25        16558     26-04-22      1/5/2022      2/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 18        2.0           RT2           others            NaN    Checked Out
# 19        2.0           RT2           others            5.0    Checked Out
# 20        1.0           RT2     makeyourtrip            NaN    Checked Out
# 21        3.0           RT2           others            NaN      Cancelled
# 22        1.0           RT2   direct offline            NaN      Cancelled
#
#     revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("room_category")
room_category_grp.get_group("RT3").head(5)
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 39  May012216558RT31        16558     27-04-22      1/5/2022      3/5/2022
# 40  May012216558RT32        16558     24-04-22      1/5/2022      6/5/2022
# 41  May012216558RT33        16558     26-04-22      1/5/2022      7/5/2022
# 42  May012216558RT34        16558     29-04-22      1/5/2022      2/5/2022
# 43  May012216558RT35        16558     29-04-22      1/5/2022      4/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 39        3.0           RT3           others            3.0    Checked Out
# 40        4.0           RT3     makeyourtrip            NaN    Checked Out
# 41        2.0           RT3     makeyourtrip            NaN    Checked Out
# 42        1.0           RT3           others            5.0    Checked Out
# 43        NaN           RT3           others            NaN    Checked Out
#
#     revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("room_category")
room_category_grp.get_group("RT4").head(5)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 47   May012216558RT41        16558     26-04-22      1/5/2022      3/5/2022
# 48   May012216558RT42        16558     27-04-22      1/5/2022      2/5/2022
# 49   May012216558RT43        16558     29-04-22      1/5/2022      4/5/2022
# 137  May012216559RT41        16559     27-04-22      1/5/2022      7/5/2022
# 138  May012216559RT42        16559    11/4/2022      1/5/2022      3/5/2022
#
#      no_guests room_category booking_platform  ratings_given booking_status  \
# 47         2.0           RT4          logtrip            NaN      Cancelled
# 48         1.0           RT4         tripster            NaN    Checked Out
# 49         2.0           RT4   direct offline            NaN      Cancelled
# 137        4.0           RT4           others            NaN    Checked Out
# 138        2.0           RT4   direct offline            NaN      Cancelled
#
#      revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("booking_platform")
room_category_grp.get_group("direct online").head(5)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 0    May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 4    May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 38  May012216558RT221        16558     25-04-22      1/5/2022      3/5/2022
# 57   May012216559RT18        16559     28-04-22      1/5/2022      3/5/2022
# 76   May012216559RT22        16559     28-04-22      1/5/2022      6/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 0        -3.0           RT1    direct online            1.0    Checked Out
# 4         4.0           RT1    direct online            5.0    Checked Out
# 38        2.0           RT2    direct online            5.0    Checked Out
# 57        1.0           RT1    direct online            NaN      Cancelled
# 76        2.0           RT2    direct online            3.0    Checked Out
#
#     revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("booking_platform")
room_category_grp.get_group("direct offline").head(5)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 16  May012216558RT117        16558     29-04-22      1/5/2022      2/5/2022
# 22   May012216558RT25        16558     26-04-22      1/5/2022      2/5/2022
# 23   May012216558RT26        16558     27-04-22      1/5/2022      2/5/2022
# 24   May012216558RT27        16558     26-04-22      1/5/2022      7/5/2022
# 32  May012216558RT215        16558     29-04-22      1/5/2022      4/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 16        3.0           RT1   direct offline            NaN    Checked Out
# 22        1.0           RT2   direct offline            NaN      Cancelled
# 23        2.0           RT2   direct offline            4.0    Checked Out
# 24        3.0           RT2   direct offline            NaN      Cancelled
# 32        2.0           RT2   direct offline            NaN        No Show
#
#     revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("booking_platform")
room_category_grp.get_group("logtrip").head(5)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 2    May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 7    May012216558RT18        16558     26-04-22      1/5/2022      3/5/2022
# 11  May012216558RT112        16558     26-04-22      1/5/2022      2/5/2022
# 13  May012216558RT114        16558     30-04-22      1/5/2022      5/5/2022
# 26   May012216558RT29        16558     25-04-22      1/5/2022      2/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 2         2.0           RT1          logtrip            5.0    Checked Out
# 7         2.0           RT1          logtrip            NaN        No Show
# 11        2.0           RT1          logtrip            5.0    Checked Out
# 13        1.0           RT1          logtrip            NaN      Cancelled
# 26        2.0           RT2          logtrip            NaN    Checked Out
#
#     revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("booking_platform")
room_category_grp.get_group("makeyourtrip").head(5)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 10  May012216558RT111        16558     29-04-22      1/5/2022      7/5/2022
# 12  May012216558RT113        16558     26-04-22      1/5/2022      7/5/2022
# 20   May012216558RT23        16558    10/4/2022      1/5/2022      7/5/2022
# 28  May012216558RT211        16558     30-04-22      1/5/2022      7/5/2022
# 34  May012216558RT217        16558     29-04-22      1/5/2022      7/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 10        1.0           RT1     makeyourtrip            5.0    Checked Out
# 12        2.0           RT1     makeyourtrip            5.0    Checked Out
# 20        1.0           RT2     makeyourtrip            NaN    Checked Out
# 28        2.0           RT2     makeyourtrip            NaN      Cancelled
# 34        4.0           RT2     makeyourtrip            NaN      Cancelled
#
#     revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("booking_platform")
room_category_grp.get_group("tripster").head(5)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 8    May012216558RT19        16558     30-04-22      1/5/2022      2/5/2022
# 37  May012216558RT220        16558     27-04-22      1/5/2022      4/5/2022
# 48   May012216558RT42        16558     27-04-22      1/5/2022      2/5/2022
# 52   May012216559RT13        16559     27-04-22      1/5/2022      2/5/2022
# 55   May012216559RT16        16559    11/4/2022      1/5/2022      2/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 8         2.0           RT1         tripster            NaN    Checked Out
# 37        2.0           RT2         tripster            NaN    Checked Out
# 48        1.0           RT4         tripster            NaN    Checked Out
# 52        1.0           RT1         tripster            NaN      Cancelled
# 55        2.0           RT1         tripster            NaN    Checked Out
#
#     revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("booking_platform")
room_category_grp.get_group("others").head(5)
# Out:
#           booking_id  property_id booking_date check_in_date checkout_date  \
# 1   May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 3   May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 5   May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 6   May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 9  May012216558RT110        16558     28-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 1        2.0           RT1           others            NaN      Cancelled
# 3       -2.0           RT1           others            NaN      Cancelled
# 5        2.0           RT1           others            4.0    Checked Out
# 6        2.0           RT1           others            NaN      Cancelled
# 9        1.0           RT1           others            4.0    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("booking_status")
room_category_grp.get_group("Cancelled").head(5)
# Out:
#            booking_id  property_id booking_date check_in_date checkout_date  \
# 1    May012216558RT12        16558     30-04-22      1/5/2022      2/5/2022
# 3    May012216558RT14        16558     28-04-22      1/5/2022      2/5/2022
# 6    May012216558RT17        16558     28-04-22      1/5/2022      6/5/2022
# 13  May012216558RT114        16558     30-04-22      1/5/2022      5/5/2022
# 21   May012216558RT24        16558     29-04-22      1/5/2022      3/5/2022
#
#     no_guests room_category booking_platform  ratings_given booking_status  \
# 1         2.0           RT1           others            NaN      Cancelled
# 3        -2.0           RT1           others            NaN      Cancelled
# 6         2.0           RT1           others            NaN      Cancelled
# 13        1.0           RT1          logtrip            NaN      Cancelled
# 21        3.0           RT2           others            NaN      Cancelled
#
#     revenue_generated  revenue_realized
# ...

# %%
room_category_grp=booking.groupby("booking_status")
room_category_grp.get_group("Checked Out").head(5)
# Out:
#          booking_id  property_id booking_date check_in_date checkout_date  \
# 0  May012216558RT11        16558     27-04-22      1/5/2022      2/5/2022
# 2  May012216558RT13        16558     28-04-22      1/5/2022      4/5/2022
# 4  May012216558RT15        16558     27-04-22      1/5/2022      2/5/2022
# 5  May012216558RT16        16558     1/5/2022      1/5/2022      3/5/2022
# 8  May012216558RT19        16558     30-04-22      1/5/2022      2/5/2022
#
#    no_guests room_category booking_platform  ratings_given booking_status  \
# 0       -3.0           RT1    direct online            1.0    Checked Out
# 2        2.0           RT1          logtrip            5.0    Checked Out
# 4        4.0           RT1    direct online            5.0    Checked Out
# 5        2.0           RT1           others            4.0    Checked Out
# 8        2.0           RT1         tripster            NaN    Checked Out
#
#    revenue_generated  revenue_realized
# ...

# %% [markdown]
# ## **2. Fact Aggregated Bookings**

# %% [markdown]
# ### EXPLORATION

# %%
agg_booking.shape
# Out:
# (9200, 5)

# %%
agg_booking.head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
agg_booking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9200 entries, 0 to 9199
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   property_id          9200 non-null   int64
#  1   check_in_date        9200 non-null   object
#  2   room_category        9200 non-null   object
#  3   successful_bookings  9200 non-null   int64
#  4   capacity             9198 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 359.5+ KB

# %%
agg_booking.describe()
# Out:
#         property_id  successful_bookings     capacity
# count   9200.000000          9200.000000  9198.000000
# mean   18040.640000            14.655761    25.280496
# std     1099.818325             7.736170    11.442080
# min    16558.000000             1.000000     3.000000
# 25%    17558.000000             9.000000    18.000000
# 50%    17564.000000            14.000000    25.000000
# 75%    18563.000000            19.000000    34.000000
# max    19563.000000           123.000000    50.000000

# %%
agg_booking.room_category.unique()
# Out:
# array(['RT1', 'RT2', 'RT3', 'RT4'], dtype=object)

# %%
agg_booking.room_category.value_counts()
# Out:
# room_category
# RT1    2300
# RT2    2300
# RT3    2300
# RT4    2300
# Name: count, dtype: int64

# %%
room_category_grp=agg_booking.groupby("room_category")
room_category_grp.get_group("RT1").head(5)
# Out:
#    property_id check_in_date room_category  successful_bookings  capacity
# 0        16559      1-May-22           RT1                   25      30.0
# 1        19562      1-May-22           RT1                   28      30.0
# 2        19563      1-May-22           RT1                   23      30.0
# 3        17558      1-May-22           RT1                   30      19.0
# 4        16558      1-May-22           RT1                   18      19.0

# %%
room_category_grp=agg_booking.groupby("room_category")
room_category_grp.get_group("RT2").head(5)
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 24        19562      1-May-22           RT2                   23      23.0
# 25        18563      1-May-22           RT2                   21      29.0
# 26        17561      1-May-22           RT2                   32      36.0
# 27        17558      1-May-22           RT2                   38      50.0
# 28        16562      1-May-22           RT2                   30      43.0

# %%
room_category_grp=agg_booking.groupby("room_category")
room_category_grp.get_group("RT3").head(5)
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 49        19563      1-May-22           RT3                   20      29.0
# 51        19562      1-May-22           RT3                   25      29.0
# 52        19561      1-May-22           RT3                   23      29.0
# 53        18562      1-May-22           RT3                   28      29.0
# 54        17558      1-May-22           RT3                   21      27.0

# %%
room_category_grp=agg_booking.groupby("room_category")
room_category_grp.get_group("RT4").head(5)
# Out:
#     property_id check_in_date room_category  successful_bookings  capacity
# 75        19559      1-May-22           RT4                    2       3.0
# 76        16562      1-May-22           RT4                    4       6.0
# 77        17558      1-May-22           RT4                    4       6.0
# 78        17562      1-May-22           RT4                    4       6.0
# 79        19563      1-May-22           RT4                    4       6.0

# %% [markdown]
# ## **3. DIM DATE**

# %% [markdown]
# ### EXPLORATION

# %%
date.shape
# Out:
# (92, 4)

# %%
date.head(5)
# Out:
#         date  mmm yy week no  day_type
# 0  01-May-22  May 22    W 19   weekend
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      92 non-null     object
#  1   mmm yy    92 non-null     object
#  2   week no   92 non-null     object
#  3   day_type  92 non-null     object
# dtypes: object(4)
# memory usage: 3.0+ KB

# %%
date.describe()
# Out:
#              date  mmm yy week no  day_type
# count          92      92      92        92
# unique         92       3      14         2
# top     01-May-22  May 22    W 19  weekeday
# freq            1      31       7        65

# %%
date.day_type.unique()
# Out:
# array(['weekend', 'weekeday'], dtype=object)

# %%
date.day_type.value_counts()
# Out:
# day_type
# weekeday    65
# weekend     27
# Name: count, dtype: int64

# %%
date_grp=date.groupby("day_type")
date_grp.get_group("weekeday").head(5)
# Out:
#         date  mmm yy week no  day_type
# 1  02-May-22  May 22    W 19  weekeday
# 2  03-May-22  May 22    W 19  weekeday
# 3  04-May-22  May 22    W 19  weekeday
# 4  05-May-22  May 22    W 19  weekeday
# 5  06-May-22  May 22    W 19  weekeday

# %%
date_grp=date.groupby("day_type")
date_grp.get_group("weekend").head(5)
# Out:
#          date  mmm yy week no day_type
# 0   01-May-22  May 22    W 19  weekend
# 6   07-May-22  May 22    W 19  weekend
# 7   08-May-22  May 22    W 20  weekend
# 13  14-May-22  May 22    W 20  weekend
# 14  15-May-22  May 22    W 21  weekend

# %% [markdown]
# ## **4. DIM HOTEL**

# %% [markdown]
# ### EXPLORATION

# %%
hotel.shape
# Out:
# (25, 4)

# %%
hotel.head(5)
# Out:
#    property_id     property_name  category    city
# 0        16558     Radison Elite    Luxury   Delhi
# 1        16559  Radison standard    Luxury  Mumbai
# 2        16560      Radison City  Business   Delhi
# 3        16561       Radison Blu    Luxury   Delhi
# 4        16562       Radison Bay    Luxury   Delhi

# %%
hotel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_id    25 non-null     int64
#  1   property_name  25 non-null     object
#  2   category       25 non-null     object
#  3   city           25 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 928.0+ bytes

# %%
hotel.describe()
# Out:
#         property_id
# count     25.000000
# mean   18040.640000
# std     1122.436371
# min    16558.000000
# 25%    17558.000000
# 50%    17564.000000
# 75%    18563.000000
# max    19563.000000

# %%
hotel.category.unique()
# Out:
# array(['Luxury', 'Business'], dtype=object)

# %%
hotel.city.unique()
# Out:
# array(['Delhi', 'Mumbai', 'Hyderabad', 'Bangalore'], dtype=object)

# %%
hotel.property_name.value_counts()
# Out:
# property_name
# Radison Elite       4
# Radison standard    4
# Radison City        4
# Radison Blu         4
# Radison Bay         4
# Radison palace      4
# Radison Seasons     1
# Name: count, dtype: int64

# %%
hotel.category.value_counts()
# Out:
# category
# Luxury      16
# Business     9
# Name: count, dtype: int64

# %%
hotel.city.value_counts()
# Out:
# city
# Mumbai       8
# Hyderabad    6
# Bangalore    6
# Delhi        5
# Name: count, dtype: int64

# %%
hotel_grp=hotel.groupby("category")
hotel_grp.get_group("Luxury").head(5)
# Out:
#    property_id     property_name category    city
# 0        16558     Radison Elite   Luxury   Delhi
# 1        16559  Radison standard   Luxury  Mumbai
# 3        16561       Radison Blu   Luxury   Delhi
# 4        16562       Radison Bay   Luxury   Delhi
# 6        17558     Radison Elite   Luxury  Mumbai

# %%
hotel_grp=hotel.groupby("category")
hotel_grp.get_group("Business").head(5)
# Out:
#     property_id   property_name  category       city
# 2         16560    Radison City  Business      Delhi
# 5         16563  Radison palace  Business      Delhi
# 8         17560    Radison City  Business     Mumbai
# 11        17563  Radison palace  Business     Mumbai
# 14        18560    Radison City  Business  Hyderabad

# %%
hotel_grp=hotel.groupby("city")
hotel_grp.get_group("Delhi").head(5)
# Out:
#    property_id   property_name  category   city
# 0        16558   Radison Elite    Luxury  Delhi
# 2        16560    Radison City  Business  Delhi
# 3        16561     Radison Blu    Luxury  Delhi
# 4        16562     Radison Bay    Luxury  Delhi
# 5        16563  Radison palace  Business  Delhi

# %%
hotel_grp=hotel.groupby("city")
hotel_grp.get_group("Mumbai").head(5)
# Out:
#    property_id     property_name  category    city
# 1        16559  Radison standard    Luxury  Mumbai
# 6        17558     Radison Elite    Luxury  Mumbai
# 7        17559  Radison standard    Luxury  Mumbai
# 8        17560      Radison City  Business  Mumbai
# 9        17561       Radison Blu    Luxury  Mumbai

# %%
hotel_grp=hotel.groupby("city")
hotel_grp.get_group("Hyderabad").head(5)
# Out:
#     property_id     property_name  category       city
# 12        18558     Radison Elite    Luxury  Hyderabad
# 13        18559  Radison standard    Luxury  Hyderabad
# 14        18560      Radison City  Business  Hyderabad
# 15        18561       Radison Blu    Luxury  Hyderabad
# 16        18562       Radison Bay    Luxury  Hyderabad

# %% [markdown]
# ## **5**.**DIM** **ROOM**

# %% [markdown]
# ### EXPLORATION

# %%
rooms.shape
rooms
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
rooms.head(5)
# Out:
#   room_id    room_class
# 0     RT1      Standard
# 1     RT2         Elite
# 2     RT3       Premium
# 3     RT4  Presidential

# %%
rooms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   room_id     4 non-null      object
#  1   room_class  4 non-null      object
# dtypes: object(2)
# memory usage: 192.0+ bytes

# %%
rooms.describe()
# Out:
#        room_id room_class
# count        4          4
# unique       4          4
# top        RT1   Standard
# freq         1          1

# %%
rooms.room_class.unique()
# Out:
# array(['Standard', 'Elite', 'Premium', 'Presidential'], dtype=object)

# %%
rooms.room_class.value_counts()
# Out:
# room_class
# Standard        1
# Elite           1
# Premium         1
# Presidential    1
# Name: count, dtype: int64
